# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = zip(lats, lngs)
#coordinates

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 731

# %%
#cities

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b2b5e11ce27842f30a84fe665ada7dbb

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | provideniya
# Processing Record 2 of Set 1 | salalah
# Processing Record 3 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | sabla
# Processing Record 6 of Set 1 | vila velha
# Processing Record 7 of Set 1 | nanortalik
# Processing Record 8 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | ostrovnoy
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | sarakhs
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | touros
# Processing Record 17 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 1 | laguna
# Processing Record 19 of Set 1 | mocuba
# Processing Record 20 of Set 1 | portland
# Processing Record 21 of Set 1 | fort nelson
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | torbay
# Processing Record 24 of Set 1 | auki
# Processing Record 25 of Set 1 | esperance
# Processing Record 26 of Set 1 | bintulu
# Processing Record 27 of Set 1 | marawi
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | konstantinovka
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | kungalv
# Processing Record 34 of Set 1 | castro
# Processing Record 35 of Set 1 | cherskiy
# Processing Record 36 of Set 1 | sesheke
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | inirida
# Processing Record 40 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | kumluca
# Processing Record 43 of Set 1 | willowmore
# Processing Record 44 of Set 1 | general roca
# Processing Record 45 of Set 1 | keti bandar
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | moengo
# Processing Record 49 of Set 1 | terney
# Processing Record 50 of Set 1 | bathsheba
# Processing Record 1 of Set 2 | thompson
# Processing Record 2 of Set 2 | talnakh
# Processing Record 3 of Set 2 | pacific grove
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | roebourne
# Processing Record 6 of Set 2 | nyurba
# Processing Record 7 of Set 2 | fairbanks
# Processing Record 8 of Set 2 | tasiilaq
# Processing Record 9 of Set 2 | new lenox
# Processing Record 10 of Set 2 | malanje
# Processing Record 11 of Set 2 | novyy urengoy
# Processing Record 12 of Set 2 | dikson
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | kodiak
# Processing Record 15 of Set 2 | saldanha
# Processing Record 16 of Set 2 | caravelas
# Processing Record 17 of Set 2 | port blair
# Processing Record 18 of Set 2 | saint-pierre
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | nizhniy tsasuchey
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | ayan
# Processing Record 23 of Set 2 | hope
# Processing Record 24 of Set 2 | zhigansk
# City not found. Skipping...
# Processing Record 25 of Set 2 | ijaki
# City not found. Skipping...
# Processing Record 26 of Set 2 | eyl
# Processing Record 27 of Set 2 | kavaratti
# Processing Record 28 of Set 2 | clyde river
# Processing Record 29 of Set 2 | ahipara
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | kaitangata
# Processing Record 32 of Set 2 | verkhovazhye
# Processing Record 33 of Set 2 | upernavik
# Processing Record 34 of Set 2 | lagoa
# Processing Record 35 of Set 2 | labrea
# Processing Record 36 of Set 2 | kavieng
# Processing Record 37 of Set 2 | narsaq
# Processing Record 38 of Set 2 | hasaki
# Processing Record 39 of Set 2 | romny
# Processing Record 40 of Set 2 | flinders
# Processing Record 41 of Set 2 | cidreira
# Processing Record 42 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 2 | vieques
# Processing Record 44 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 2 | katsuura
# Processing Record 46 of Set 2 | kapaa
# Processing Record 47 of Set 2 | newtownards
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | saint-philippe
# Processing Record 50 of Set 2 | sur
# Processing Record 1 of Set 3 | souillac
# Processing Record 2 of Set 3 | gat
# Processing Record 3 of Set 3 | kununurra
# Processing Record 4 of Set 3 | monte cristi
# City not found. Skipping...
# Processing Record 5 of Set 3 | yulara
# Processing Record 6 of Set 3 | vardo
# Processing Record 7 of Set 3 | saint george
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 3 | peace river
# Processing Record 11 of Set 3 | saskylakh
# Processing Record 12 of Set 3 | prieska
# Processing Record 13 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 3 | ketchikan
# Processing Record 15 of Set 3 | cabo san lucas
# Processing Record 16 of Set 3 | hilo
# Processing Record 17 of Set 3 | khatanga
# Processing Record 18 of Set 3 | hithadhoo
# Processing Record 19 of Set 3 | nikolskoye
# Processing Record 20 of Set 3 | hay river
# Processing Record 21 of Set 3 | muisne
# Processing Record 22 of Set 3 | hobart
# Processing Record 23 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 3 | arlit
# Processing Record 25 of Set 3 | camara de lobos
# Processing Record 26 of Set 3 | hamilton
# Processing Record 27 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 3 | belmonte
# Processing Record 29 of Set 3 | bhimunipatnam
# Processing Record 30 of Set 3 | mahebourg
# Processing Record 31 of Set 3 | cockburn town
# Processing Record 32 of Set 3 | villarrobledo
# Processing Record 33 of Set 3 | ribeira grande
# Processing Record 34 of Set 3 | bethel
# Processing Record 35 of Set 3 | ambilobe
# Processing Record 36 of Set 3 | bengkulu
# Processing Record 37 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 3 | rafai
# Processing Record 39 of Set 3 | gabu
# Processing Record 40 of Set 3 | atuona
# Processing Record 41 of Set 3 | san patricio
# Processing Record 42 of Set 3 | berdigestyakh
# Processing Record 43 of Set 3 | olga
# Processing Record 44 of Set 3 | tiksi
# Processing Record 45 of Set 3 | victoria
# Processing Record 46 of Set 3 | calama
# Processing Record 47 of Set 3 | barra
# Processing Record 48 of Set 3 | shingu
# Processing Record 49 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 3 | deh rawud
# City not found. Skipping...
# Processing Record 1 of Set 4 | vostok
# Processing Record 2 of Set 4 | leningradskiy
# Processing Record 3 of Set 4 | talara
# Processing Record 4 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 4 | malakal
# Processing Record 6 of Set 4 | ambon
# Processing Record 7 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 4 | chuy
# Processing Record 9 of Set 4 | venado tuerto
# Processing Record 10 of Set 4 | werther
# Processing Record 11 of Set 4 | gualaquiza
# Processing Record 12 of Set 4 | nelson bay
# Processing Record 13 of Set 4 | grindavik
# Processing Record 14 of Set 4 | paamiut
# Processing Record 15 of Set 4 | ilo
# Processing Record 16 of Set 4 | bridlington
# Processing Record 17 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 18 of Set 4 | bara
# Processing Record 19 of Set 4 | linguere
# Processing Record 20 of Set 4 | tunxi
# City not found. Skipping...
# Processing Record 21 of Set 4 | jamestown
# Processing Record 22 of Set 4 | wodonga
# Processing Record 23 of Set 4 | hokitika
# Processing Record 24 of Set 4 | artyom
# Processing Record 25 of Set 4 | atar
# Processing Record 26 of Set 4 | ancud
# Processing Record 27 of Set 4 | trinidad
# Processing Record 28 of Set 4 | clarence town
# Processing Record 29 of Set 4 | hoquiam
# Processing Record 30 of Set 4 | barrow
# Processing Record 31 of Set 4 | lavrentiya
# Processing Record 32 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 4 | aripuana
# Processing Record 34 of Set 4 | sohag
# Processing Record 35 of Set 4 | atasu
# Processing Record 36 of Set 4 | hovd
# Processing Record 37 of Set 4 | tuy hoa
# Processing Record 38 of Set 4 | luderitz
# Processing Record 39 of Set 4 | chokurdakh
# Processing Record 40 of Set 4 | corrente
# Processing Record 41 of Set 4 | banki
# Processing Record 42 of Set 4 | severo-kurilsk
# Processing Record 43 of Set 4 | nago
# Processing Record 44 of Set 4 | kibaya
# Processing Record 45 of Set 4 | bambous virieux
# Processing Record 46 of Set 4 | sao filipe
# Processing Record 47 of Set 4 | koslan
# Processing Record 48 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 49 of Set 4 | tatarsk
# Processing Record 50 of Set 4 | dauphin
# Processing Record 1 of Set 5 | tefe
# Processing Record 2 of Set 5 | port elizabeth
# Processing Record 3 of Set 5 | yaring
# Processing Record 4 of Set 5 | bonthe
# Processing Record 5 of Set 5 | minab
# Processing Record 6 of Set 5 | panacan
# Processing Record 7 of Set 5 | victoria point
# Processing Record 8 of Set 5 | phumi samraong
# City not found. Skipping...
# Processing Record 9 of Set 5 | deer lake
# Processing Record 10 of Set 5 | zabol
# Processing Record 11 of Set 5 | mahibadhoo
# Processing Record 12 of Set 5 | husavik
# Processing Record 13 of Set 5 | balkanabat
# Processing Record 14 of Set 5 | follonica
# Processing Record 15 of Set 5 | la ronge
# Processing Record 16 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 5 | angoche
# Processing Record 18 of Set 5 | chakulia
# Processing Record 19 of Set 5 | alofi
# Processing Record 20 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 5 | cravo norte
# Processing Record 22 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 5 | rong kwang
# Processing Record 24 of Set 5 | vestmannaeyjar
# Processing Record 25 of Set 5 | norman wells
# Processing Record 26 of Set 5 | spornoye
# Processing Record 27 of Set 5 | svetlogorsk
# Processing Record 28 of Set 5 | beyneu
# Processing Record 29 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 30 of Set 5 | huarmey
# Processing Record 31 of Set 5 | emerald
# Processing Record 32 of Set 5 | tual
# Processing Record 33 of Set 5 | airai
# Processing Record 34 of Set 5 | neverkino
# Processing Record 35 of Set 5 | itarema
# Processing Record 36 of Set 5 | les cayes
# Processing Record 37 of Set 5 | lata
# Processing Record 38 of Set 5 | pangnirtung
# Processing Record 39 of Set 5 | meulaboh
# Processing Record 40 of Set 5 | abha
# Processing Record 41 of Set 5 | chone
# Processing Record 42 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 5 | serowe
# Processing Record 44 of Set 5 | sao francisco
# Processing Record 45 of Set 5 | mubende
# Processing Record 46 of Set 5 | richards bay
# Processing Record 47 of Set 5 | east london
# Processing Record 48 of Set 5 | cairns
# Processing Record 49 of Set 5 | fukue
# Processing Record 50 of Set 5 | aitape
# Processing Record 1 of Set 6 | dunedin
# Processing Record 2 of Set 6 | ginir
# Processing Record 3 of Set 6 | chimore
# Processing Record 4 of Set 6 | portoferraio
# Processing Record 5 of Set 6 | eureka
# Processing Record 6 of Set 6 | komsomolskiy
# Processing Record 7 of Set 6 | digby
# Processing Record 8 of Set 6 | thongwa
# Processing Record 9 of Set 6 | mahanoro
# Processing Record 10 of Set 6 | anadyr
# Processing Record 11 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 6 | vernon
# Processing Record 13 of Set 6 | presidencia roque saenz pena
# Processing Record 14 of Set 6 | gigmoto
# Processing Record 15 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 6 | ust-kuyga
# Processing Record 17 of Set 6 | leshukonskoye
# Processing Record 18 of Set 6 | coahuayana
# Processing Record 19 of Set 6 | macenta
# Processing Record 20 of Set 6 | floro
# Processing Record 21 of Set 6 | chikwawa
# Processing Record 22 of Set 6 | craig
# Processing Record 23 of Set 6 | ngunguru
# Processing Record 24 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 6 | coquimbo
# Processing Record 26 of Set 6 | simao
# Processing Record 27 of Set 6 | miyako
# Processing Record 28 of Set 6 | bilma
# Processing Record 29 of Set 6 | melfi
# Processing Record 30 of Set 6 | arraial do cabo
# Processing Record 31 of Set 6 | ola
# Processing Record 32 of Set 6 | raalte
# Processing Record 33 of Set 6 | ilulissat
# Processing Record 34 of Set 6 | dingle
# Processing Record 35 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 36 of Set 6 | inuvik
# Processing Record 37 of Set 6 | shimoda
# Processing Record 38 of Set 6 | ekibastuz
# Processing Record 39 of Set 6 | kuandian
# Processing Record 40 of Set 6 | goldsboro
# Processing Record 41 of Set 6 | ewa beach
# Processing Record 42 of Set 6 | fortuna foothills
# Processing Record 43 of Set 6 | sindand
# City not found. Skipping...
# Processing Record 44 of Set 6 | namibe
# Processing Record 45 of Set 6 | ponta do sol
# Processing Record 46 of Set 6 | aksu
# Processing Record 47 of Set 6 | hami
# Processing Record 48 of Set 6 | fayetteville
# Processing Record 49 of Set 6 | abu zabad
# Processing Record 50 of Set 6 | saint-joseph
# Processing Record 1 of Set 7 | camocim
# Processing Record 2 of Set 7 | krasnyy oktyabr
# Processing Record 3 of Set 7 | dekar
# Processing Record 4 of Set 7 | jalu
# Processing Record 5 of Set 7 | pisco
# Processing Record 6 of Set 7 | srednekolymsk
# Processing Record 7 of Set 7 | turek
# Processing Record 8 of Set 7 | ponta delgada
# Processing Record 9 of Set 7 | champerico
# Processing Record 10 of Set 7 | urumqi
# Processing Record 11 of Set 7 | varadero
# Processing Record 12 of Set 7 | lorengau
# Processing Record 13 of Set 7 | blackwater
# Processing Record 14 of Set 7 | bandarbeyla
# Processing Record 15 of Set 7 | ambo
# Processing Record 16 of Set 7 | kautokeino
# Processing Record 17 of Set 7 | tarko-sale
# Processing Record 18 of Set 7 | omboue
# Processing Record 19 of Set 7 | ucluelet
# Processing Record 20 of Set 7 | acapulco
# Processing Record 21 of Set 7 | rabo de peixe
# Processing Record 22 of Set 7 | korla
# Processing Record 23 of Set 7 | teguise
# Processing Record 24 of Set 7 | kenai
# Processing Record 25 of Set 7 | marsh harbour
# Processing Record 26 of Set 7 | imbituba
# Processing Record 27 of Set 7 | avera
# Processing Record 28 of Set 7 | charlestown
# Processing Record 29 of Set 7 | krasnyy
# Processing Record 30 of Set 7 | hervey bay
# Processing Record 31 of Set 7 | belen
# Processing Record 32 of Set 7 | novoanninskiy
# Processing Record 33 of Set 7 | sao joaquim
# Processing Record 34 of Set 7 | zachary
# Processing Record 35 of Set 7 | oktyabrskoye
# Processing Record 36 of Set 7 | kozhva
# Processing Record 37 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 38 of Set 7 | kulhudhuffushi
# Processing Record 39 of Set 7 | portobelo
# Processing Record 40 of Set 7 | lucea
# Processing Record 41 of Set 7 | faanui
# Processing Record 42 of Set 7 | camacha
# Processing Record 43 of Set 7 | gonzalez
# Processing Record 44 of Set 7 | chincholi
# Processing Record 45 of Set 7 | maryborough
# Processing Record 46 of Set 7 | kuopio
# Processing Record 47 of Set 7 | lompoc
# Processing Record 48 of Set 7 | mount gambier
# Processing Record 49 of Set 7 | yakeshi
# Processing Record 50 of Set 7 | sechura
# Processing Record 1 of Set 8 | maturin
# Processing Record 2 of Set 8 | swiecie
# Processing Record 3 of Set 8 | killybegs
# Processing Record 4 of Set 8 | kendari
# Processing Record 5 of Set 8 | faya
# Processing Record 6 of Set 8 | devils lake
# Processing Record 7 of Set 8 | galdar
# Processing Record 8 of Set 8 | vanimo
# Processing Record 9 of Set 8 | vanino
# Processing Record 10 of Set 8 | rochegda
# Processing Record 11 of Set 8 | zeya
# Processing Record 12 of Set 8 | kalianget
# Processing Record 13 of Set 8 | petrovskaya
# Processing Record 14 of Set 8 | starosubkhangulovo
# Processing Record 15 of Set 8 | zyryanovsk
# Processing Record 16 of Set 8 | hammond
# Processing Record 17 of Set 8 | kasongo
# Processing Record 18 of Set 8 | stephenville
# Processing Record 19 of Set 8 | razole
# Processing Record 20 of Set 8 | magdagachi
# Processing Record 21 of Set 8 | manta
# Processing Record 22 of Set 8 | hambantota
# Processing Record 23 of Set 8 | kuching
# Processing Record 24 of Set 8 | tupik
# Processing Record 25 of Set 8 | bontang
# Processing Record 26 of Set 8 | severnoye
# Processing Record 27 of Set 8 | batagay-alyta
# Processing Record 28 of Set 8 | kroya
# Processing Record 29 of Set 8 | ormond beach
# Processing Record 30 of Set 8 | sangar
# Processing Record 31 of Set 8 | tawang
# Processing Record 32 of Set 8 | mosquera
# Processing Record 33 of Set 8 | hailey
# Processing Record 34 of Set 8 | waipawa
# Processing Record 35 of Set 8 | makubetsu
# Processing Record 36 of Set 8 | poum
# Processing Record 37 of Set 8 | mount pleasant
# Processing Record 38 of Set 8 | port antonio
# Processing Record 39 of Set 8 | axim
# Processing Record 40 of Set 8 | misratah
# Processing Record 41 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 8 | alekseyevsk
# Processing Record 43 of Set 8 | tagab
# Processing Record 44 of Set 8 | roma
# Processing Record 45 of Set 8 | totoral
# Processing Record 46 of Set 8 | san quintin
# Processing Record 47 of Set 8 | koumac
# Processing Record 48 of Set 8 | sapao
# City not found. Skipping...
# Processing Record 49 of Set 8 | pevek
# Processing Record 50 of Set 8 | niquero
# Processing Record 1 of Set 9 | klaksvik
# Processing Record 2 of Set 9 | praia da vitoria
# Processing Record 3 of Set 9 | kalabo
# Processing Record 4 of Set 9 | haines junction
# Processing Record 5 of Set 9 | ceres
# Processing Record 6 of Set 9 | palaiokhora
# City not found. Skipping...
# Processing Record 7 of Set 9 | ajaccio
# Processing Record 8 of Set 9 | skibbereen
# Processing Record 9 of Set 9 | scarborough
# Processing Record 10 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 9 | saint-francois
# Processing Record 12 of Set 9 | samarai
# Processing Record 13 of Set 9 | zhuhai
# Processing Record 14 of Set 9 | bequimao
# Processing Record 15 of Set 9 | aklavik
# Processing Record 16 of Set 9 | monrovia
# Processing Record 17 of Set 9 | longyearbyen
# Processing Record 18 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 9 | baruun-urt
# Processing Record 20 of Set 9 | porto santo
# Processing Record 21 of Set 9 | karatau
# Processing Record 22 of Set 9 | banda aceh
# Processing Record 23 of Set 9 | tongzi
# Processing Record 24 of Set 9 | vila franca do campo
# Processing Record 25 of Set 9 | mnogovershinnyy
# Processing Record 26 of Set 9 | tuatapere
# Processing Record 27 of Set 9 | mackay
# Processing Record 28 of Set 9 | nome
# Processing Record 29 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 9 | barroualie
# City not found. Skipping...
# Processing Record 31 of Set 9 | okha
# Processing Record 32 of Set 9 | carnarvon
# Processing Record 33 of Set 9 | galveston
# Processing Record 34 of Set 9 | doha
# Processing Record 35 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 36 of Set 9 | sug-aksy
# City not found. Skipping...
# Processing Record 37 of Set 9 | khairpur
# Processing Record 38 of Set 9 | isangel
# Processing Record 39 of Set 9 | jega
# Processing Record 40 of Set 9 | coihaique
# Processing Record 41 of Set 9 | fauske
# Processing Record 42 of Set 9 | port-gentil
# Processing Record 43 of Set 9 | kokstad
# Processing Record 44 of Set 9 | barillas
# Processing Record 45 of Set 9 | larkana
# Processing Record 46 of Set 9 | moranbah
# Processing Record 47 of Set 9 | havre-saint-pierre
# Processing Record 48 of Set 9 | monroe
# Processing Record 49 of Set 9 | harnosand
# Processing Record 50 of Set 9 | harer
# Processing Record 1 of Set 10 | antofagasta
# Processing Record 2 of Set 10 | wajid
# Processing Record 3 of Set 10 | san juan
# Processing Record 4 of Set 10 | kinango
# Processing Record 5 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 6 of Set 10 | buchanan
# Processing Record 7 of Set 10 | kirakira
# Processing Record 8 of Set 10 | inverell
# Processing Record 9 of Set 10 | kahului
# Processing Record 10 of Set 10 | singkang
# Processing Record 11 of Set 10 | marmora
# Processing Record 12 of Set 10 | strezhevoy
# Processing Record 13 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 14 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 10 | beloha
# Processing Record 16 of Set 10 | mazabuka
# Processing Record 17 of Set 10 | hede
# Processing Record 18 of Set 10 | inverness
# Processing Record 19 of Set 10 | eyrarbakki
# Processing Record 20 of Set 10 | carutapera
# Processing Record 21 of Set 10 | takoradi
# Processing Record 22 of Set 10 | songwa
# Processing Record 23 of Set 10 | nouadhibou
# Processing Record 24 of Set 10 | alugan
# Processing Record 25 of Set 10 | pitimbu
# Processing Record 26 of Set 10 | konokovo
# Processing Record 27 of Set 10 | kysyl-syr
# Processing Record 28 of Set 10 | greenland
# Processing Record 29 of Set 10 | necochea
# Processing Record 30 of Set 10 | noumea
# Processing Record 31 of Set 10 | naze
# Processing Record 32 of Set 10 | houma
# Processing Record 33 of Set 10 | sayla
# Processing Record 34 of Set 10 | winnemucca
# Processing Record 35 of Set 10 | nuuk
# Processing Record 36 of Set 10 | nemuro
# Processing Record 37 of Set 10 | ust-ordynskiy
# Processing Record 38 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 10 | porto novo
# Processing Record 40 of Set 10 | labuhan
# Processing Record 41 of Set 10 | horsham
# Processing Record 42 of Set 10 | san estanislao
# Processing Record 43 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 10 | beira
# Processing Record 45 of Set 10 | razdolnoye
# Processing Record 46 of Set 10 | qaqortoq
# Processing Record 47 of Set 10 | zhanakorgan
# Processing Record 48 of Set 10 | qasigiannguit
# Processing Record 49 of Set 10 | krasnogorsk
# Processing Record 50 of Set 10 | henties bay
# Processing Record 1 of Set 11 | salinopolis
# Processing Record 2 of Set 11 | stokmarknes
# Processing Record 3 of Set 11 | kindu
# Processing Record 4 of Set 11 | tandil
# Processing Record 5 of Set 11 | union
# Processing Record 6 of Set 11 | asau
# Processing Record 7 of Set 11 | miri
# Processing Record 8 of Set 11 | awjilah
# Processing Record 9 of Set 11 | copiapo
# Processing Record 10 of Set 11 | padang
# Processing Record 11 of Set 11 | la rioja
# Processing Record 12 of Set 11 | praia
# Processing Record 13 of Set 11 | ilhabela
# Processing Record 14 of Set 11 | basco
# Processing Record 15 of Set 11 | cartagena
# Processing Record 16 of Set 11 | lekoni
# Processing Record 17 of Set 11 | guabito
# Processing Record 18 of Set 11 | pingdingshan
# Processing Record 19 of Set 11 | zhengjiatun
# Processing Record 20 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 21 of Set 11 | toora-khem
# Processing Record 22 of Set 11 | orel-izumrud
# Processing Record 23 of Set 11 | southbridge
# Processing Record 24 of Set 11 | guerrero negro
# Processing Record 25 of Set 11 | shellbrook
# Processing Record 26 of Set 11 | grand gaube
# Processing Record 27 of Set 11 | kimbe
# Processing Record 28 of Set 11 | bilibino
# Processing Record 29 of Set 11 | port hardy
# Processing Record 30 of Set 11 | jalaun
# Processing Record 31 of Set 11 | maldonado
# Processing Record 32 of Set 11 | safaqis
# City not found. Skipping...
# Processing Record 33 of Set 11 | coolum beach
# Processing Record 34 of Set 11 | anshun
# Processing Record 35 of Set 11 | tabarqah
# City not found. Skipping...
# Processing Record 36 of Set 11 | port lincoln
# Processing Record 37 of Set 11 | colares
# Processing Record 38 of Set 11 | loiza
# Processing Record 39 of Set 11 | mpika
# Processing Record 40 of Set 11 | arivonimamo
# Processing Record 41 of Set 11 | ushtobe
# Processing Record 42 of Set 11 | stekolnyy
# City not found. Skipping...
# Processing Record 43 of Set 11 | selma
# Processing Record 44 of Set 11 | del rio
# Processing Record 45 of Set 11 | boddam
# Processing Record 46 of Set 11 | moree
# Processing Record 47 of Set 11 | caldas novas
# Processing Record 48 of Set 11 | soe
# Processing Record 49 of Set 11 | mount isa
# Processing Record 50 of Set 11 | thinadhoo
# Processing Record 1 of Set 12 | qandala
# Processing Record 2 of Set 12 | puerto gaitan
# Processing Record 3 of Set 12 | rio gallegos
# Processing Record 4 of Set 12 | bubaque
# Processing Record 5 of Set 12 | inta
# Processing Record 6 of Set 12 | batagay
# Processing Record 7 of Set 12 | buraydah
# Processing Record 8 of Set 12 | nizhniy kuranakh
# Processing Record 9 of Set 12 | sitka
# Processing Record 10 of Set 12 | kolbermoor
# Processing Record 11 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 12 | riyadh
# Processing Record 13 of Set 12 | susanville
# Processing Record 14 of Set 12 | lasa
# Processing Record 15 of Set 12 | christchurch
# Processing Record 16 of Set 12 | shache
# Processing Record 17 of Set 12 | nara
# Processing Record 18 of Set 12 | constitucion
# Processing Record 19 of Set 12 | zhezkazgan
# Processing Record 20 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 12 | beringovskiy
# Processing Record 22 of Set 12 | vicuna
# Processing Record 23 of Set 12 | pozo colorado
# Processing Record 24 of Set 12 | punta alta
# Processing Record 25 of Set 12 | prado
# Processing Record 26 of Set 12 | little current
# Processing Record 27 of Set 12 | pierre
# Processing Record 28 of Set 12 | veraval
# Processing Record 29 of Set 12 | sao joao da barra
# Processing Record 30 of Set 12 | anderson
# Processing Record 31 of Set 12 | safaga
# Processing Record 32 of Set 12 | waddan
# Processing Record 33 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 34 of Set 12 | kaka
# Processing Record 35 of Set 12 | port macquarie
# Processing Record 36 of Set 12 | olafsvik
# Processing Record 37 of Set 12 | kpandae
# Processing Record 38 of Set 12 | batavia
# Processing Record 39 of Set 12 | hereford
# Processing Record 40 of Set 12 | abnub
# Processing Record 41 of Set 12 | celestun
# Processing Record 42 of Set 12 | egvekinot
# Processing Record 43 of Set 12 | salisbury
# Processing Record 44 of Set 12 | the valley
# Processing Record 45 of Set 12 | iberia
# Processing Record 46 of Set 12 | wad madani
# Processing Record 47 of Set 12 | dillon
# Processing Record 48 of Set 12 | tukrah
# Processing Record 49 of Set 12 | tahe
# Processing Record 50 of Set 12 | isla vista
# Processing Record 1 of Set 13 | severo-yeniseyskiy
# Processing Record 2 of Set 13 | palmer
# Processing Record 3 of Set 13 | new kensington
# Processing Record 4 of Set 13 | halifax
# Processing Record 5 of Set 13 | kiunga
# Processing Record 6 of Set 13 | kichmengskiy gorodok
# Processing Record 7 of Set 13 | shibetsu
# Processing Record 8 of Set 13 | portalegre
# Processing Record 9 of Set 13 | krasnoselkup
# Processing Record 10 of Set 13 | kinsale
# Processing Record 11 of Set 13 | gunnedah
# Processing Record 12 of Set 13 | kaili
# Processing Record 13 of Set 13 | velluru
# City not found. Skipping...
# Processing Record 14 of Set 13 | jacareacanga
# Processing Record 15 of Set 13 | goderich
# Processing Record 16 of Set 13 | russell
# Processing Record 17 of Set 13 | yilan
# Processing Record 18 of Set 13 | peterhead
# Processing Record 19 of Set 13 | lerwick
# Processing Record 20 of Set 13 | chapais
# Processing Record 21 of Set 13 | bud
# Processing Record 22 of Set 13 | boa vista
# Processing Record 23 of Set 13 | fortuna
# Processing Record 24 of Set 13 | bati
# Processing Record 25 of Set 13 | berezovyy
# Processing Record 26 of Set 13 | sept-iles
# Processing Record 27 of Set 13 | anito
# Processing Record 28 of Set 13 | rudbar
# Processing Record 29 of Set 13 | hopewell
# Processing Record 30 of Set 13 | nioro
# Processing Record 31 of Set 13 | pula
# Processing Record 32 of Set 13 | kasongo-lunda
# Processing Record 33 of Set 13 | kanor
# Processing Record 34 of Set 13 | brookhaven
# Processing Record 35 of Set 13 | stepnogorsk
# Processing Record 36 of Set 13 | le port
# Processing Record 37 of Set 13 | gualeguay
# Processing Record 38 of Set 13 | phalombe
# Processing Record 39 of Set 13 | visby
# Processing Record 40 of Set 13 | kruisfontein
# Processing Record 41 of Set 13 | gusau
# Processing Record 42 of Set 13 | nueva imperial
# Processing Record 43 of Set 13 | suzun
# Processing Record 44 of Set 13 | kogon
# Processing Record 45 of Set 13 | trincomalee
# Processing Record 46 of Set 13 | makakilo city
# Processing Record 47 of Set 13 | tecoanapa
# Processing Record 48 of Set 13 | sainte-rose
# Processing Record 49 of Set 13 | half moon bay
# Processing Record 50 of Set 13 | levittown
# Processing Record 1 of Set 14 | hofn
# Processing Record 2 of Set 14 | bekhtery
# Processing Record 3 of Set 14 | formosa do rio preto
# Processing Record 4 of Set 14 | manjacaze
# Processing Record 5 of Set 14 | lazo
# Processing Record 6 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 14 | benemerito de las americas
# Processing Record 8 of Set 14 | milkovo
# Processing Record 9 of Set 14 | mopipi
# Processing Record 10 of Set 14 | pangai
# Processing Record 11 of Set 14 | orlik
# Processing Record 12 of Set 14 | letlhakane
# Processing Record 13 of Set 14 | marquette
# Processing Record 14 of Set 14 | dalianwan
# Processing Record 15 of Set 14 | griffith
# Processing Record 16 of Set 14 | malindi
# Processing Record 17 of Set 14 | daxian
# City not found. Skipping...
# Processing Record 18 of Set 14 | tres arroyos
# Processing Record 19 of Set 14 | malmo
# Processing Record 20 of Set 14 | bin qirdan
# Processing Record 21 of Set 14 | chara
# Processing Record 22 of Set 14 | margate
# Processing Record 23 of Set 14 | mao
# Processing Record 24 of Set 14 | keetmanshoop
# Processing Record 25 of Set 14 | namatanai
# Processing Record 26 of Set 14 | pilani
# Processing Record 27 of Set 14 | goya
# Processing Record 28 of Set 14 | kutum
# Processing Record 29 of Set 14 | adre
# Processing Record 30 of Set 14 | massakory
# Processing Record 31 of Set 14 | norsup
# Processing Record 32 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 14 | tonantins
# Processing Record 34 of Set 14 | tiarei
# Processing Record 35 of Set 14 | bunia
# Processing Record 36 of Set 14 | roswell
# Processing Record 37 of Set 14 | alamosa
# Processing Record 38 of Set 14 | oksfjord
# Processing Record 39 of Set 14 | gemena
# Processing Record 40 of Set 14 | embonas
# Processing Record 41 of Set 14 | walvis bay
# Processing Record 42 of Set 14 | baillif
# Processing Record 43 of Set 14 | slave lake
# Processing Record 44 of Set 14 | itahari
# City not found. Skipping...
# Processing Record 45 of Set 14 | clevelandia
# Processing Record 46 of Set 14 | san lorenzo
# Processing Record 47 of Set 14 | toamasina
# Processing Record 48 of Set 14 | pervomayskoye
# Processing Record 49 of Set 14 | lumeje
# Processing Record 50 of Set 14 | nizwa
# Processing Record 1 of Set 15 | port hedland
# Processing Record 2 of Set 15 | santiago del estero
# Processing Record 3 of Set 15 | ballina
# Processing Record 4 of Set 15 | muros
# Processing Record 5 of Set 15 | karimpur
# Processing Record 6 of Set 15 | sultanpur
# Processing Record 7 of Set 15 | gizo
# Processing Record 8 of Set 15 | puerto escondido
# Processing Record 9 of Set 15 | san ramon
# Processing Record 10 of Set 15 | saint-georges
# Processing Record 11 of Set 15 | geraldton
# Processing Record 12 of Set 15 | matara
# Processing Record 13 of Set 15 | izumo
# Processing Record 14 of Set 15 | hoi an
# Processing Record 15 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 16 of Set 15 | pringsewu
# Processing Record 17 of Set 15 | sioux lookout
# Processing Record 18 of Set 15 | adrar
# Processing Record 19 of Set 15 | starobaltachevo
# Processing Record 20 of Set 15 | dharchula
# Processing Record 21 of Set 15 | alexandria
# Processing Record 22 of Set 15 | sovetskiy
# Processing Record 23 of Set 15 | barraute
# Processing Record 24 of Set 15 | savannakhet
# Processing Record 25 of Set 15 | vallenar
# Processing Record 26 of Set 15 | pirot
# Processing Record 27 of Set 15 | paraiso
# Processing Record 28 of Set 15 | samfya
# Processing Record 29 of Set 15 | zhigalovo
# Processing Record 30 of Set 15 | opuwo
# Processing Record 31 of Set 15 | san luis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#city_data

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Provideniya  64.3833 -173.3000      6.80        78          90       13.42
# 1      Salalah  17.0151   54.0924     69.80        68           0        4.61
# 2    Busselton -33.6500  115.3333     55.00        94          74       10.27
# 3        Sabla  12.7525    4.7077     76.93        16          10        8.79
# 4   Vila Velha -20.3297  -40.2925     88.00        69          20       16.11
# 5   Nanortalik  60.1432  -45.2371     15.30        83           0        7.56
# 6       Albany  42.6001  -73.9662     27.00        74         100        7.85
# 7    Ostrovnoy  68.0531   39.5131      7.14        94         100       18.68
# 8  New Norfolk -42.7826  147.0587     53.01        69           3        1.01
# 9     Hermanus -34.4187   19.2345     64.99        81           1        6.60
#
#   Country                 Date      Description
# 0      RU  2021-01-26 20:12:02  overcast clouds
# 1      OM  2021-01-26 20:11:27        clear sky
# 2      AU  2021-01-26 20:11:15    broken clouds
# 3      NG  2021-01-26 20:17:33        clear sky
# 4      BR  2021-01-26 20:11:56       few clouds
# 5      GL  2021-01-26 20:11:43        clear sky
# 6      US  2021-01-26 20:10:08       light snow
# 7      RU  2021-01-26 20:08:56       light snow
# 8      AU  2021-01-26 20:11:17        clear sky
# 9      ZA  2021-01-26 20:11:17        clear sky

# %%
city_data_df.drop(['Date'],axis =1)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Provideniya  64.3833 -173.3000      6.80        78          90
# 1        Salalah  17.0151   54.0924     69.80        68           0
# 2      Busselton -33.6500  115.3333     55.00        94          74
# 3          Sabla  12.7525    4.7077     76.93        16          10
# 4     Vila Velha -20.3297  -40.2925     88.00        69          20
# ..           ...      ...       ...       ...       ...         ...
# 666      Paraiso   9.8383  -83.8656     78.80        50          20
# 667       Samfya -11.3649   29.5565     64.72        91         100
# 668    Zhigalovo  54.8097  105.1578    -24.36        82         100
# 669        Opuwo -18.0607   13.8400     71.02        65          93
# 670     San Luis -33.2950  -66.3356     91.62        27          82
#
#      Wind Speed Country      Description
# 0         13.42      RU  overcast clouds
# 1          4.61      OM        clear sky
# 2         10.27      AU    broken clouds
# 3          8.79      NG        clear sky
# 4         16.11      BR       few clouds
# ..          ...     ...              ...
# 666       18.41      CR       few clouds
# 667        4.47      ZM       light rain
# 668        1.92      RU  overcast clouds
# 669       12.30      NA  overcast clouds
# 670       14.25      AR    broken clouds
#
# [671 rows x 9 columns]

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Description"]

# %%
city_data_df=city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Provideniya      RU  64.3833 -173.3000      6.80        78          90
# 1      Salalah      OM  17.0151   54.0924     69.80        68           0
# 2    Busselton      AU -33.6500  115.3333     55.00        94          74
# 3        Sabla      NG  12.7525    4.7077     76.93        16          10
# 4   Vila Velha      BR -20.3297  -40.2925     88.00        69          20
#
#    Wind Speed      Description
# 0       13.42  overcast clouds
# 1        4.61        clear sky
# 2       10.27    broken clouds
# 3        8.79        clear sky
# 4       16.11       few clouds

# %%
city_data_df.to_csv (r'C:\Users\18323\Desktop\Classwork\Module_6\Weather_Database\WeatherPy_Database.csv', index = False, header=True)
